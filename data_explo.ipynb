# %%
import pandas as pd

# %%
# load airports.csv
airports = pd.read_csv('FlightMap/data/airports.csv')

# Drop rows where city is missing
airports = airports.dropna(subset=['City'])

# %%
# load airlines.csv
airlines = pd.read_csv('FlightMap/data/airlines.csv')

# %%
# load routes.csv
routes = pd.read_csv('FlightMap/data/routes.csv')
routes
# Out:
#       Airline Airline ID Source airport Source airport ID Destination airport  \
# 0          2B        410            AER              2965                 KZN
# 1          2B        410            ASF              2966                 KZN
# 2          2B        410            ASF              2966                 MRV
# 3          2B        410            CEK              2968                 KZN
# 4          2B        410            CEK              2968                 OVB
# ...       ...        ...            ...               ...                 ...
# 67658      ZL       4178            WYA              6334                 ADL
# 67659      ZM      19016            DME              4029                 FRU
# 67660      ZM      19016            FRU              2912                 DME
# 67661      ZM      19016            FRU              2912                 OSS
# 67662      ZM      19016            OSS              2913                 FRU
#
# ...

# %%
# load routes_with_distance.csv
routes_with_distance = pd.read_csv('FlightMap/data/routes_with_distance.csv')
routes_with_distance
# Out:
#       Source Airport Destination airport Source IATA  Source Latitude  \
# 0                AER                 KZN         AER        43.449902
# 1                ASF                 KZN         ASF        46.283298
# 2                ASF                 MRV         ASF        46.283298
# 3                CEK                 KZN         CEK        55.305801
# 4                CEK                 OVB         CEK        55.305801
# ...              ...                 ...         ...              ...
# 66929            WYA                 ADL         WYA       -33.058899
# 66930            DME                 FRU         DME        55.408798
# 66931            FRU                 DME         FRU        43.061298
# 66932            FRU                 OSS         FRU        43.061298
# 66933            OSS                 FRU         OSS        40.609001
#
#        Source Longitude Destination IATA  Destination Latitude  \
# ...
